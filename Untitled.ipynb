# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
# Collecting validators>=0.2
#   Using cached validators-0.20.0-py3-none-any.whl
# Collecting pympler>=0.9
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# Requirement already satisfied: python-dateutil in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Collecting tzlocal>=1.1
#   Using cached tzlocal-4.3-py3-none-any.whl (20 kB)
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# Requirement already satisfied: numpy in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (3.19.1)
# Requirement already satisfied: watchdog in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: cachetools>=4.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Collecting blinker>=1.0.0
#   Using cached blinker-1.6.1-py3-none-any.whl (13 kB)
# Collecting rich>=10.11.0
#   Using cached rich-13.3.3-py3-none-any.whl (238 kB)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Requirement already satisfied: click>=7.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Collecting altair<5,>=3.2.0
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# Requirement already satisfied: packaging>=14.1 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (21.3)
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: requests>=2.4 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: pandas<2,>=0.25 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (1.4.2)
# Collecting pyarrow>=4.0
#   Using cached pyarrow-11.0.0-cp39-cp39-win_amd64.whl (20.6 MB)
# Requirement already satisfied: toml in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: entrypoints in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jinja2 in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (2.11.3)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.4.0)
# Collecting typing-extensions>=3.10.0.0
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: colorama in c:\users\55839\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\55839\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\55839\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\55839\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\55839\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\55839\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\55839\anaconda3\lib\site-packages (from pandas<2,>=0.25->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\55839\anaconda3\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\55839\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached Pygments-2.15.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\55839\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in c:\users\55839\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2023.3)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\55839\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Installing collected packages: typing-extensions, pytz-deprecation-shim, pygments, markdown-it-py, gitdb, validators, tzlocal, rich, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'c:\\users\\55839\\anaconda3\\lib\\site-packages\\typing_extensions-4.1.1.dist-info\\'
# Collecting streamlit
#   Using cached streamlit-1.21.0-py2.py3-none-any.whl (9.7 MB)
# Requirement already satisfied: cachetools>=4.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.1.1)
# Requirement already satisfied: packaging>=14.1 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (21.3)
# Requirement already satisfied: toml in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Collecting tzlocal>=1.1
#   Using cached tzlocal-4.3-py3-none-any.whl (20 kB)
# Collecting pympler>=0.9
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# Collecting validators>=0.2
#   Using cached validators-0.20.0-py3-none-any.whl
# Collecting rich>=10.11.0
#   Using cached rich-13.3.3-py3-none-any.whl (238 kB)
# Requirement already satisfied: click>=7.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (8.0.4)
# Collecting altair<5,>=3.2.0
#   Using cached altair-4.2.2-py3-none-any.whl (813 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: requests>=2.4 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.27.1)
# Requirement already satisfied: watchdog in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: numpy in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (1.21.5)
# Requirement already satisfied: python-dateutil in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (4.11.3)
# Collecting gitpython!=3.1.19
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# Requirement already satisfied: tornado>=6.0.3 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (6.1)
# Collecting pydeck>=0.1.dev5
#   Using cached pydeck-0.8.0-py2.py3-none-any.whl (4.7 MB)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (3.19.1)
# Collecting blinker>=1.0.0
#   Using cached blinker-1.6.1-py3-none-any.whl (13 kB)
# Requirement already satisfied: pandas<2,>=0.25 in c:\users\55839\anaconda3\lib\site-packages (from streamlit) (1.4.2)
# Collecting pyarrow>=4.0
#   Using cached pyarrow-11.0.0-cp39-cp39-win_amd64.whl (20.6 MB)
# Requirement already satisfied: entrypoints in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.4)
# Requirement already satisfied: toolz in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (0.11.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\55839\anaconda3\lib\site-packages (from altair<5,>=3.2.0->streamlit) (2.11.3)
# Collecting typing-extensions>=3.10.0.0
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: colorama in c:\users\55839\anaconda3\lib\site-packages (from click>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\55839\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\55839\anaconda3\lib\site-packages (from importlib-metadata>=1.4->streamlit) (3.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\55839\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\55839\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\55839\anaconda3\lib\site-packages (from packaging>=14.1->streamlit) (3.0.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\55839\anaconda3\lib\site-packages (from pandas<2,>=0.25->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\55839\anaconda3\lib\site-packages (from jinja2->altair<5,>=3.2.0->streamlit) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\55839\anaconda3\lib\site-packages (from python-dateutil->streamlit) (1.16.0)
# WARNING: Error parsing requirements for typing-extensions: [Errno 2] No such file or directory: 'c:\\users\\55839\\anaconda3\\lib\\site-packages\\typing_extensions-4.1.1.dist-info\\METADATA'
# WARNING: Error parsing requirements for pygments: [Errno 2] No such file or directory: 'c:\\users\\55839\\anaconda3\\lib\\site-packages\\Pygments-2.11.2.dist-info\\METADATA'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# jupyter-server 1.13.5 requires pywinpty<2; os_name == "nt", but you have pywinpty 2.0.2 which is incompatible.
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\55839\anaconda3\lib\site-packages (from requests>=2.4->streamlit) (2.0.4)
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Using cached markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached Pygments-2.15.0-py3-none-any.whl (1.1 MB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\55839\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->streamlit) (0.1.2)
# Requirement already satisfied: tzdata in c:\users\55839\anaconda3\lib\site-packages (from tzlocal>=1.1->streamlit) (2023.3)
# Collecting pytz-deprecation-shim
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\55839\anaconda3\lib\site-packages (from validators>=0.2->streamlit) (5.1.1)
# Installing collected packages: typing-extensions, pytz-deprecation-shim, pygments, markdown-it-py, gitdb, validators, tzlocal, rich, pympler, pydeck, pyarrow, gitpython, blinker, altair, streamlit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Can't uninstall 'typing-extensions'. No files were found to uninstall.
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Can't uninstall 'Pygments'. No files were found to uninstall.
# Successfully installed altair-4.2.2 blinker-1.6.1 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-2.2.0 pyarrow-11.0.0 pydeck-0.8.0 pygments-2.15.0 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.3.3 streamlit-1.21.0 typing-extensions-4.5.0 tzlocal-4.3 validators-0.20.0

# %%
import time
import numpy as np
import pandas as pd
import streamlit as st
import sklearn.metrics
import sklearn.datasets
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
st.write("*Formação Engenheiro de Machine Learning*")
st.write("*Deploy de Modelos de Machine Learning*")
st.write("*Deploy de Aplicações Preditivas com Streamlit*")
st.title("Regressão Logística")
# Out:
# 2023-04-10 22:48:45.823
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\55839\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %%
st.sidebar.header('Dataset e Hiperparâmetros')
st.sidebar.markdown("""**Selecione o Dataset Desejado**""")
Dataset = st.sidebar.selectbox('Dataset',('Iris', 'Wine', 'Breast Cancer'))
Split = st.sidebar.slider('Escolha o Percentual de Divisão dos Dados em Treino e Teste (padrão = 70/30):', 0.1, 0.9, 0.70)
st.sidebar.markdown("""**Selecione os Hiperparâmetros Para o Modelo de Regressão Logística**""")
Solver = st.sidebar.selectbox('Algoritmo', ('lbfgs', 'newton-cg', 'liblinear', 'sag'))
Penality = st.sidebar.radio("Regularização:", ('none', 'l1', 'l2', 'elasticnet'))
Tol = st.sidebar.text_input("Tolerância Para Critério de Parada (default = 1e-4):", "1e-4")
Max_Iteration = st.sidebar.text_input("Número de Iterações (default = 50):", "50")

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
parameters = { 'Penality':Penality, 'Tol':Tol, 'Max_Iteration':Max_Iteration, 'Solver':Solver }

# %%
def carrega_dataset(dataset):

    # Carrega o dataset
    if dataset == 'Iris':
        dados = sklearn.datasets.load_iris()
    elif dataset == 'Wine':
         dados = sklearn.datasets.load_wine()
    elif dataset == 'Breast Cancer':
         dados = sklearn.datasets.load_breast_cancer()
    
    return dados

# %%
# Função para preparar os dados e fazer a divisão em treino e teste
def prepara_dados(dados, split):

    # Divide os dados de acordo com o valor de split definido pelo usuário
    X_treino, X_teste, y_treino, y_teste = train_test_split(dados.data, dados.target, test_size = float(split), random_state = 42)

    # Prepara o scaler para padronização
    scaler = MinMaxScaler()

    # Fit e transform nos dados de treino
    X_treino = scaler.fit_transform(X_treino)

    # Apenas transform nos dados de teste
    X_teste = scaler.transform(X_teste)

    return (X_treino, X_teste, y_treino, y_teste)

# %%
def cria_modelo(parameters):
    
    # Extrai os dados de treino e teste
    X_treino, X_teste, y_treino, y_teste = prepara_dados(Data, Split) 

    # Cria o modelo
    # https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
    clf = LogisticRegression(penalty = parameters['Penality'], 
                             solver = parameters['Solver'], 
                             max_iter = int(parameters['Max_Iteration']), 
                             tol = float(parameters['Tol']))

    # Treina o modelo
    clf = clf.fit(X_treino, y_treino)

    # Faz previsões
    prediction = clf.predict(X_teste)
    
    # Calcula a acurácia
    accuracy = sklearn.metrics.accuracy_score(y_teste, prediction)

    # Calcula a confusion matrix
    cm = confusion_matrix(y_teste, prediction)

    # Dicionário com os resultados
    dict_value = {"modelo":clf, "acuracia": accuracy, "previsao":prediction, "y_real": y_teste, "Metricas":cm, "X_teste": X_teste }
       
    return(dict_value)
    
    return(X_treino, X_teste, y_treino, y_teste)

##### Programando o Corpo da Aplicação Web ##### 

# Resumo dos dados
st.markdown("""Resumo dos Dados""")
st.write("Nome do Dataset:", Dataset)

# Carrega o dataset escolhido pelo usuário
Data = carrega_dataset(Dataset)

# Extrai a variável alvo
targets = Data.target_names

# Prepara o dataframe com os dados
Dataframe = pd.DataFrame (Data.data, columns = Data.feature_names)
Dataframe['target'] = pd.Series(Data.target)
Dataframe['target labels'] = pd.Series(targets[i] for i in Data.target)

# Mostra o dataset selecionado pelo usuário
st.write("Visão Geral dos Atributos:")
st.write(Dataframe)

##### Programando o Botão de Ação ##### 

if(st.sidebar.button("Clique Para Treinar o Modelo de Regressão Logística")):
    
    # Barra de progressão
    with st.spinner('Carregando o Dataset...'):
        time.sleep(1)

    # Info de sucesso
    st.success("Dataset Carregado!")
    
    # Cria e treina o modelo
    modelo = cria_modelo(parameters) 
    
    # Barra de progressão
    my_bar = st.progress(0)

    # Mostra a barra de progressão com percentual de conclusão
    for percent_complete in range(100):
        time.sleep(0.1)
        my_bar.progress(percent_complete + 1)

    # Info para o usuário
    with st.spinner('Treinando o Modelo...'):
        time.sleep(1)

    # Info de sucesso
    st.success("Modelo Treinado") 

    # Extrai os labels reais
    labels_reais = [targets[i] for i in modelo["y_real"]]

    # Extrai os labels previstos
    labels_previstos = [targets[i] for i in modelo["previsao"]]

    # Sub título
    st.subheader("Previsões do Modelo nos Dados de Teste")

    # Mostra o resultado
    st.write(pd.DataFrame({"Valor Real" : modelo["y_real"], 
                           "Label Real" : labels_reais, 
                           "Valor Previsto" : modelo["previsao"], 
                           "Label Previsto" :  labels_previstos,}))
    
    # Extrai as métricas
    matriz = modelo["Metricas"]

    # Sub título
    st.subheader("Matriz de Confusão nos Dados de Teste")

    # Mostra a matriz de confusão
    st.write(matriz)

    # Mostra a acurácia
    st.write("Acurácia do Modelo:", modelo["acuracia"])

    # Obrigado
    st.write("Obrigado por usar esta app do Streamlit!")
